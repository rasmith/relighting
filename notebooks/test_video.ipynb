# %%
import cv2 as cv

# %%
import numpy as np

# %%
cap = cv.VideoCapture('videos/IMG_0163.m4v')

# %%
cap.get(cv.CAP_PROP_FRAME_COUNT)
# Out:
# 1171.0

# %%
cap.get(cv.CAP_PROP_FRAME_WIDTH)
# Out:
# 720.0

# %%
cap.get(cv.CAP_PROP_FRAME_HEIGHT)
# Out:
# 1280.0

# %%
cap.get(cv.CAP_PROP_MODE)
# Out:
# 0.0

# %%
frames = np.zeros((1280, 720, 3, 1171), dtype=np.uint8)

# %%
frames.shape
# Out:
# (1280, 720, 3, 1171)

# %%
i = 0

# %%
while cap.isOpened():

# %%
  _, f = cap.read()

# %%
  frames[:,:,:,i] = f

# %%
  kps.append(sift.detect(gray,None))

# %%
  i += 1

# %%
sift = cv.xfeatures2d.SIFT_create()

# %%
f = frames[:,:,:,0]

# %%
gray = cv.cvtColor(frames[:,:,:,0], cv.COLOR_BGR2GRAY)

# %%
kp = sift.detect(gray,None)

# %%
frame=cv.drawKeypoints(gray,kp,frame)

# %%
frame.shape
# Out:
# (1280, 720, 3)

# %%
from matplotlib import pyplot as plt

# %%
plt.rcParams["figure.figsize"] = (20,10)

# %%
plt.imshow(frame)
